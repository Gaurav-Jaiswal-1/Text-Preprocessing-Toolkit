# %%
# Out:
# c:\Users\Gaurav\OneDrive\Desktop\TPT\.venv\lib\site-packages\Text_Preprocessing_Toolkit\__init__.py

# %%
from spellchecker import SpellChecker

spell = SpellChecker()
misspelled = spell.unknown(['speelingg', 'errors'])

print("Misspelled Words:", misspelled)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from spellchecker import SpellChecker
#       3 spell = SpellChecker()
#       4 misspelled = spell.unknown(['speelingg', 'errors'])
#
# ImportError: cannot import name 'SpellChecker' from 'spellchecker' (unknown location)

# %%
from spellchecker import SpellChecker

spell = SpellChecker()
misspelled = spell.unknown(['speelingg', 'errors'])

print("Misspelled Words:", misspelled)
# Out:
# Misspelled Words: {'speelingg'}

# %%
from spellchecker import SpellChecker

# Initialize SpellChecker
spell = SpellChecker()

# Check for misspelled words
misspelled = spell.unknown(['speelingg', 'errors'])
print("Misspelled Words:", misspelled)
# Out:
# Misspelled Words: {'speelingg'}

# %%
# 3/12/24 -

# %%
# import string
# import re
# import pandas as pd
# from collections import Counter
# from nltk.corpus import stopwords, wordnet
# from nltk.stem import PorterStemmer, WordNetLemmatizer
# from nltk import pos_tag, word_tokenize
# from spellchecker import SpellChecker
# from typing import List, Optional, Union
# from IPython.display import display
# import logging

# # Download required NLTK resources
# import nltk
# nltk.download("averaged_perceptron_tagger", quiet=True)
# nltk.download("wordnet", quiet=True)
# nltk.download("omw-1.4", quiet=True)
# nltk.download("stopwords", quiet=True)
# nltk.download("punkt", quiet=True)

# # Configure logging
# logging.basicConfig(level=logging.INFO, format="%(asctime)s - %(levelname)s - %(message)s")


# class TextPreprocessor:
#     """
#     Comprehensive text preprocessing class for NLP tasks.
#     """
#     __version__ = "1.0.0"  # Updated version with streamlined functionality

#     def __init__(self, custom_stopwords: Optional[List[str]] = None) -> None:
#         """
#         Initialize the text preprocessor.

#         Parameters:
#         custom_stopwords (list, optional): List of additional stopwords to remove.
#         """
#         self.stopwords = set(stopwords.words("english"))
#         if custom_stopwords:
#             self.stopwords.update(custom_stopwords)

#         self.lemmatizer = WordNetLemmatizer()
#         self.stemmer = PorterStemmer()
#         self.spell_checker = SpellChecker()

#         self.wordnet_map = {
#             "N": wordnet.NOUN,
#             "V": wordnet.VERB,
#             "J": wordnet.ADJ,
#             "R": wordnet.ADV,
#         }

#     def _apply_func(self, func, text: Optional[str]) -> Optional[str]:
#         """
#         Safely apply a function to text and log errors.
#         """
#         try:
#             return func(text)
#         except Exception as e:
#             logging.error(f"Error in '{func.__name__}': {e}")
#             return text

#     def tokenize(self, text: Optional[str]) -> List[str]:
#         """Tokenize text into words."""
#         return word_tokenize(text) if text else []

#     def remove_punctuation(self, text: Optional[str]) -> Optional[str]:
#         """Remove punctuation from text."""
#         return text.translate(str.maketrans("", "", string.punctuation)) if text else text

#     def remove_stopwords(self, tokens: List[str]) -> List[str]:
#         """Remove stopwords from tokenized text."""
#         return [word for word in tokens if word.lower() not in self.stopwords]

#     def remove_special_characters(self, text: Optional[str]) -> Optional[str]:
#         """Remove special characters from text."""
#         return re.sub(r"[^a-zA-Z0-9\s]", "", text).strip() if text else text

#     def lemmatize_text(self, text: Optional[str]) -> Optional[str]:
#         """Lemmatize text using WordNet."""
#         if not text:
#             return text
#         tokens = self.tokenize(text)
#         pos_tags = pos_tag(tokens)
#         return " ".join(
#             self.lemmatizer.lemmatize(word, self.wordnet_map.get(pos[0].upper(), wordnet.NOUN))
#             for word, pos in pos_tags
#         )

#     def correct_spellings(self, text: Optional[str]) -> Optional[str]:
#         """Correct misspelled words in text."""
#         if not text:
#             return text
#         tokens = self.tokenize(text)
#         return " ".join(
#             [self.spell_checker.correction(word) if word in self.spell_checker else word for word in tokens]
#         )

#     def lowercase(self, text: Optional[str]) -> Optional[str]:
#         """Convert text to lowercase."""
#         return text.lower() if text else text

#     def remove_url(self, text: Optional[str]) -> Optional[str]:
#         """Remove URLs from text."""
#         return re.sub(r"https?://\S+|www\.\S+", "", text) if text else text

#     def remove_html_tags(self, text: Optional[str]) -> Optional[str]:
#         """Remove HTML tags from text."""
#         return re.sub(r"<[^>]+>", "", text) if text else text

#     def preprocess(
#         self, text: str, steps: Optional[List[str]] = None
#     ) -> Optional[str]:
#         """
#         Preprocess text with a pipeline of processing steps.

#         Parameters:
#         text (str): The input text to preprocess.
#         steps (list, optional): List of preprocessing steps in desired order.

#         Returns:
#         str: Preprocessed text.
#         """
#         if not text:
#             return text

#         steps = steps or [
#             "lowercase",
#             "remove_punctuation",
#             "remove_special_characters",
#             "remove_url",
#             "remove_html_tags",
#             "correct_spellings",
#             "lemmatize_text",
#         ]

#         for step in steps:
#             func = getattr(self, step)
#             text = self._apply_func(func, text)
#             logging.info(f"Step '{step}' completed.")
#         return text

#     def head(self, texts: Union[List[str], pd.Series], n: int = 5) -> None:
#         """
#         Display a summary of the first few entries of the dataset.

#         Parameters:
#         texts (list or pd.Series): The dataset or list of text entries.
#         n (int): Number of rows to display.
#         """
#         if isinstance(texts, (list, pd.Series)):
#             data = pd.DataFrame({"Original Text": texts[:n]})
#             data["Processed Text"] = data["Original Text"].apply(self.preprocess)
#             data["Word Count"] = data["Processed Text"].apply(lambda x: len(x.split()))
#             data["Character Count"] = data["Processed Text"].apply(len)
#             display(data)


# if __name__ == "__main__":
#     # Example usage
#     tpt = TextPreprocessor()

# %%
if __name__ == "__main__":
    # Instantiate the TextPreprocessor class
    tpt = TextPreprocessor(custom_stopwords=["example", "test"])

    # Sample text data
    sample_texts = [
        "Hello! This is an <b>example</b> sentence. Visit https://example.com for more info!",
        "NLP preprocessing includes tokenization, lemmatization, and stemming.",
        "Special characters #, $, %, &, should be removed!",
        "Check for spelling erorrs in this sentense and correct them.",
        "Stopwords like 'and', 'the', and 'is' should be removed."
    ]

    # Preprocess a single text
    processed_text = tpt.preprocess(
        sample_texts[0], 
        steps=[
            "lowercase",
            "remove_punctuation",
            "remove_special_characters",
            "remove_url",
            "remove_html_tags",
            "correct_spellings",
            "lemmatize_text"
        ]
    )
    print("Processed Text (Single):", processed_text)

    # Preprocess multiple texts and display summary
    print("\nProcessing multiple texts...")
    tpt.head(sample_texts, n=5)
# Out:
# 2024-12-07 15:33:50,667 - INFO - Step 'lowercase' completed.
# 2024-12-07 15:33:50,668 - INFO - Step 'remove_punctuation' completed.
# 2024-12-07 15:33:50,669 - INFO - Step 'remove_special_characters' completed.
# 2024-12-07 15:33:50,671 - INFO - Step 'remove_url' completed.
# 2024-12-07 15:33:50,672 - INFO - Step 'remove_html_tags' completed.
# 2024-12-07 15:33:50,749 - INFO - Step 'correct_spellings' completed.
# 2024-12-07 15:33:50,934 - INFO - Step 'lemmatize_text' completed.
# 2024-12-07 15:33:50,946 - INFO - Step 'lowercase' completed.
# 2024-12-07 15:33:50,948 - INFO - Step 'remove_punctuation' completed.
# 2024-12-07 15:33:50,949 - INFO - Step 'remove_special_characters' completed.
# 2024-12-07 15:33:50,950 - INFO - Step 'remove_url' completed.
# 2024-12-07 15:33:50,951 - INFO - Step 'remove_html_tags' completed.
# 2024-12-07 15:33:50,953 - INFO - Step 'correct_spellings' completed.
# 2024-12-07 15:33:50,955 - INFO - Step 'lemmatize_text' completed.
# 2024-12-07 15:33:50,956 - INFO - Step 'lowercase' completed.
# 2024-12-07 15:33:50,957 - INFO - Step 'remove_punctuation' completed.
# 2024-12-07 15:33:50,958 - INFO - Step 'remove_special_characters' completed.
# 2024-12-07 15:33:50,960 - INFO - Step 'remove_url' completed.
# 2024-12-07 15:33:50,961 - INFO - Step 'remove_html_tags' completed.
# 2024-12-07 15:33:50,963 - INFO - Step 'correct_spellings' completed.
# 2024-12-07 15:33:50,965 - INFO - Step 'lemmatize_text' completed.
# 2024-12-07 15:33:50,965 - INFO - Step 'lowercase' completed.
# 2024-12-07 15:33:50,966 - INFO - Step 'remove_punctuation' completed.
# 2024-12-07 15:33:50,967 - INFO - Step 'remove_special_characters' completed.
# 2024-12-07 15:33:50,968 - INFO - Step 'remove_url' completed.
# 2024-12-07 15:33:50,968 - INFO - Step 'remove_html_tags' completed.
# 2024-12-07 15:33:50,969 - INFO - Step 'correct_spellings' completed.
# 2024-12-07 15:33:50,971 - INFO - Step 'lemmatize_text' completed.
# 2024-12-07 15:33:50,973 - INFO - Step 'lowercase' completed.
# 2024-12-07 15:33:50,974 - INFO - Step 'remove_punctuation' completed.
# 2024-12-07 15:33:50,976 - INFO - Step 'remove_special_characters' completed.
# 2024-12-07 15:33:50,980 - INFO - Step 'remove_url' completed.
# 2024-12-07 15:33:50,981 - INFO - Step 'remove_html_tags' completed.
# 2024-12-07 15:33:50,983 - INFO - Step 'correct_spellings' completed.
# 2024-12-07 15:33:50,984 - INFO - Step 'lemmatize_text' completed.
# 2024-12-07 15:33:50,985 - INFO - Step 'lowercase' completed.
# 2024-12-07 15:33:50,987 - INFO - Step 'remove_punctuation' completed.
# 2024-12-07 15:33:50,988 - INFO - Step 'remove_special_characters' completed.
# 2024-12-07 15:33:50,989 - INFO - Step 'remove_url' completed.
# 2024-12-07 15:33:50,990 - INFO - Step 'remove_html_tags' completed.
# 2024-12-07 15:33:50,992 - INFO - Step 'correct_spellings' completed.
# 2024-12-07 15:33:50,993 - INFO - Step 'lemmatize_text' completed.
# Processed Text (Single): hello this be an bexampleb sentence visit httpsexamplecom for more info
#
# Processing multiple texts...
#                                        Original Text  \
# 0  Hello! This is an <b>example</b> sentence. Vis...
# 1  NLP preprocessing includes tokenization, lemma...
# 2  Special characters #, $, %, &, should be removed!
# 3  Check for spelling erorrs in this sentense and...
# 4  Stopwords like 'and', 'the', and 'is' should b...
#
#                                       Processed Text  Word Count  \
# 0  hello this be an bexampleb sentence visit http...          11
# 1  nlp preprocessing include tokenization lemmati...           7
# 2                 special character should be remove           5
# 3  check for spell erorrs in this sentense and co...          10
# 4     stopwords like and the and be should be remove           9
#
#    Character Count
# 0               71
# 1               65
# 2               34
# 3               56
# 4               46

# %%
import string
import re
import pandas as pd
from collections import Counter
from nltk.corpus import stopwords, wordnet
from nltk.stem import WordNetLemmatizer
from nltk import pos_tag, word_tokenize
from spellchecker import SpellChecker
from typing import List, Optional, Union
from IPython.display import display
import logging

# Download required NLTK resources
import nltk
nltk.download("averaged_perceptron_tagger", quiet=True)
nltk.download("wordnet", quiet=True)
nltk.download("omw-1.4", quiet=True)
nltk.download("stopwords", quiet=True)
nltk.download("punkt", quiet=True)

# Configure logging
logging.basicConfig(level=logging.INFO, format="%(asctime)s - %(levelname)s - %(message)s")

class TextPreprocessor:
    """
    Comprehensive text preprocessing class for NLP tasks.
    """
    __version__ = "1.1.0"  # Updated version with optimized code

    def __init__(self, custom_stopwords: Optional[List[str]] = None) -> None:
        """
        Initialize the text preprocessor.

        Parameters:
        custom_stopwords (list, optional): List of additional stopwords to remove.
        """
        self.stopwords = set(stopwords.words("english"))
        if custom_stopwords:
            self.stopwords.update(custom_stopwords)

        self.lemmatizer = WordNetLemmatizer()
        self.spell_checker = SpellChecker()
        self.wordnet_map = {
            "N": wordnet.NOUN,
            "V": wordnet.VERB,
            "J": wordnet.ADJ,
            "R": wordnet.ADV,
        }

    def tokenize(self, text: Optional[str]) -> List[str]:
        """Tokenize text into words."""
        return word_tokenize(text) if text else []

    def remove_punctuation(self, text: Optional[str]) -> Optional[str]:
        """Remove punctuation from text."""
        return re.sub(f"[{re.escape(string.punctuation)}]", "", text) if text else text

    def remove_stopwords(self, tokens: List[str]) -> List[str]:
        """Remove stopwords from tokenized text."""
        return [word for word in tokens if word.lower() not in self.stopwords]

    def remove_special_characters(self, text: Optional[str]) -> Optional[str]:
        """Remove special characters from text."""
        return re.sub(r"[^a-zA-Z0-9\s]", "", text).strip() if text else text

    def lemmatize_text(self, text: Optional[str]) -> Optional[str]:
        """Lemmatize text using WordNet."""
        if not text:
            return text
        tokens = self.tokenize(text)
        pos_tags = pos_tag(tokens)
        return " ".join(
            self.lemmatizer.lemmatize(word, self.wordnet_map.get(pos[0].upper(), wordnet.NOUN))
            for word, pos in pos_tags
        )

    def correct_spellings(self, text: Optional[str]) -> Optional[str]:
        """Correct misspelled words in text."""
        if not text:
            return text
        tokens = self.tokenize(text)
        return " ".join(self.spell_checker.correction(word) if word in self.spell_checker else word for word in tokens)

    def lowercase(self, text: Optional[str]) -> Optional[str]:
        """Convert text to lowercase."""
        return text.lower() if text else text

    def remove_url(self, text: Optional[str]) -> Optional[str]:
        """Remove URLs from text."""
        return re.sub(r"https?://\S+|www\.\S+", "", text) if text else text

    def remove_html_tags(self, text: Optional[str]) -> Optional[str]:
        """Remove HTML tags from text."""
        return re.sub(r"<[^>]+>", "", text) if text else text

    def preprocess(
        self, text: str, steps: Optional[List[str]] = None
    ) -> Optional[str]:
        """
        Preprocess text with a pipeline of processing steps.

        Parameters:
        text (str): The input text to preprocess.
        steps (list, optional): List of preprocessing steps in desired order.

        Returns:
        str: Preprocessed text.
        """
        if not text:
            return text

        steps = steps or [
            "lowercase",
            "remove_url",
            "remove_html_tags",
            "remove_punctuation",
            "remove_special_characters",
            "correct_spellings",
            "lemmatize_text",
        ]

        for step in steps:
            try:
                func = getattr(self, step)
                text = func(text)
                logging.info(f"Step '{step}' completed.")
            except Exception as e:
                logging.error(f"Error during step '{step}': {e}")
        return text

    def head(self, texts: Union[List[str], pd.Series], n: int = 5) -> None:
        """
        Display a summary of the first few entries of the dataset.

        Parameters:
        texts (list or pd.Series): The dataset or list of text entries.
        n (int): Number of rows to display.
        """
        if isinstance(texts, (list, pd.Series)):
            data = pd.DataFrame({"Original Text": texts[:n]})
            data["Processed Text"] = data["Original Text"].apply(self.preprocess)
            data["Word Count"] = data["Processed Text"].apply(lambda x: len(x.split()) if x else 0)
            data["Character Count"] = data["Processed Text"].apply(len)
            display(data)


if __name__ == "__main__":
    # Example usage
    tpt = TextPreprocessor()

# %%
if __name__ == "__main__":
    # Instantiate the TextPreprocessor class
    tpt = TextPreprocessor(custom_stopwords=["example", "test"])

    # Sample text data
    sample_texts = [
        "Hello! This is an <b>example</b> sentence. Visit https://example.com for more info!",
        "NLP preprocessing includes tokenization, lemmatization, and stemming.",
        "Special characters #, $, %, &, should be removed!",
        "Check for spelling erorrs in this sentense and correct them.",
        "Stopwords like 'and', 'the', and 'is' should be removed."
    ]

    # Preprocess a single text
    processed_text = tpt.preprocess(
        sample_texts[0], 
        steps=[
            "lowercase",
            "remove_punctuation",
            "remove_special_characters",
            "remove_url",
            "remove_html_tags",
            "correct_spellings",
            "lemmatize_text"
        ]
    )
    print("Processed Text (Single):", processed_text)

    # Preprocess multiple texts and display summary
    print("\nProcessing multiple texts...")
    tpt.head(sample_texts, n=5)
# Out:
# 2024-12-07 16:00:01,697 - INFO - Step 'lowercase' completed.
# 2024-12-07 16:00:01,702 - INFO - Step 'remove_punctuation' completed.
# 2024-12-07 16:00:01,703 - INFO - Step 'remove_special_characters' completed.
# 2024-12-07 16:00:01,704 - INFO - Step 'remove_url' completed.
# 2024-12-07 16:00:01,706 - INFO - Step 'remove_html_tags' completed.
# 2024-12-07 16:00:01,711 - INFO - Step 'correct_spellings' completed.
# 2024-12-07 16:00:01,786 - INFO - Step 'lemmatize_text' completed.
# 2024-12-07 16:00:01,831 - INFO - Step 'lowercase' completed.
# 2024-12-07 16:00:01,834 - INFO - Step 'remove_url' completed.
# 2024-12-07 16:00:01,836 - INFO - Step 'remove_html_tags' completed.
# 2024-12-07 16:00:01,837 - INFO - Step 'remove_punctuation' completed.
# 2024-12-07 16:00:01,839 - INFO - Step 'remove_special_characters' completed.
# 2024-12-07 16:00:01,841 - INFO - Step 'correct_spellings' completed.
# 2024-12-07 16:00:01,846 - INFO - Step 'lemmatize_text' completed.
# 2024-12-07 16:00:01,847 - INFO - Step 'lowercase' completed.
# 2024-12-07 16:00:01,849 - INFO - Step 'remove_url' completed.
# 2024-12-07 16:00:01,851 - INFO - Step 'remove_html_tags' completed.
# 2024-12-07 16:00:01,852 - INFO - Step 'remove_punctuation' completed.
# 2024-12-07 16:00:01,853 - INFO - Step 'remove_special_characters' completed.
# 2024-12-07 16:00:01,854 - INFO - Step 'correct_spellings' completed.
# 2024-12-07 16:00:01,870 - INFO - Step 'lemmatize_text' completed.
# 2024-12-07 16:00:01,871 - INFO - Step 'lowercase' completed.
# 2024-12-07 16:00:01,873 - INFO - Step 'remove_url' completed.
# 2024-12-07 16:00:01,875 - INFO - Step 'remove_html_tags' completed.
# 2024-12-07 16:00:01,876 - INFO - Step 'remove_punctuation' completed.
# 2024-12-07 16:00:01,877 - INFO - Step 'remove_special_characters' completed.
# 2024-12-07 16:00:01,878 - INFO - Step 'correct_spellings' completed.
# 2024-12-07 16:00:01,885 - INFO - Step 'lemmatize_text' completed.
# 2024-12-07 16:00:01,887 - INFO - Step 'lowercase' completed.
# 2024-12-07 16:00:01,888 - INFO - Step 'remove_url' completed.
# 2024-12-07 16:00:01,889 - INFO - Step 'remove_html_tags' completed.
# 2024-12-07 16:00:01,889 - INFO - Step 'remove_punctuation' completed.
# 2024-12-07 16:00:01,890 - INFO - Step 'remove_special_characters' completed.
# 2024-12-07 16:00:01,891 - INFO - Step 'correct_spellings' completed.
# 2024-12-07 16:00:01,900 - INFO - Step 'lemmatize_text' completed.
# 2024-12-07 16:00:01,901 - INFO - Step 'lowercase' completed.
# 2024-12-07 16:00:01,902 - INFO - Step 'remove_url' completed.
# 2024-12-07 16:00:01,903 - INFO - Step 'remove_html_tags' completed.
# 2024-12-07 16:00:01,904 - INFO - Step 'remove_punctuation' completed.
# 2024-12-07 16:00:01,905 - INFO - Step 'remove_special_characters' completed.
# 2024-12-07 16:00:01,907 - INFO - Step 'correct_spellings' completed.
# 2024-12-07 16:00:01,911 - INFO - Step 'lemmatize_text' completed.
# Processed Text (Single): hello this be an bexampleb sentence visit httpsexamplecom for more info
#
# Processing multiple texts...
#                                        Original Text  \
# 0  Hello! This is an <b>example</b> sentence. Vis...
# 1  NLP preprocessing includes tokenization, lemma...
# 2  Special characters #, $, %, &, should be removed!
# 3  Check for spelling erorrs in this sentense and...
# 4  Stopwords like 'and', 'the', and 'is' should b...
#
#                                       Processed Text  Word Count  \
# 0  hello this be an example sentence visit for mo...          10
# 1  nlp preprocessing include tokenization lemmati...           7
# 2                 special character should be remove           5
# 3  check for spell erorrs in this sentense and co...          10
# 4     stopwords like and the and be should be remove           9
#
#    Character Count
# 0               53
# 1               65
# 2               34
# 3               56
# 4               46
